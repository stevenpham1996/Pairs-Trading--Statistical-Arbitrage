# %% [markdown]
# # Introduction
# Traditional pairs trading strategies rely on strict assumptions about the relationships between securities, namely that there exists a linear relationship between candidate securities.
#
# The concept of **Mutual Information** from Information Theory allows us to loosen this linear assumption and extend the asset universe selection with polynomial relationships.
#
# The mutual information of two random variables measures the mutual dependence between two variables and is often used as a generalized version of correlation. Securities with high mutual information indicate the existence of either a linear or nonlinear relationship which can be utilized to generate a dollar neutral portfolio.
#
# The research notebook is divided into the following sections:
# <ol>
#     <li>Data Collection and Cleaning </li>
#     <li>Potential Pair Selection </li>
#     <li>Spread Modeling</li>
#     <li>Mean Reversion and Stationarity Testing</li>
#     <li>Trade Signal Generation </li>
#     <li>Backtest </li>
#     <li>Performance Summary </li>
#     <li>Conclusion </li>
# </ol>

# %% [markdown]
# # Load Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from mutual_information_pairs_functions import *

# %% [markdown]
# # Data Collection and Cleaning
#
#
# We will handle this process by the following:
# 1. **Importance**: Finding a set of stocks whose prices are below an upperbound price limit (contingent on the size of the account). The price limit is designed to ensure proper position sizing which is crucial when it comes to any arbitrage strategy.
# 2. Clean and log-transform asset prices.

# %% [markdown]
# In this research, the stock symbols of the S&P500 composite will be selected by their sectors and current bidding prices (smaller than 500 USD).
#
# **NOTE**: the selection of the S&P500 stock universe is not accounted for Survivorship Bias. *This is not expected to affect the results of our arbitrage strategy as the strategy does not rely on the performances of the individual stocks*.
#
# Data: 15 years of historical Daily Close from Yahoo Finance

# %%
sectors_list = ['Industrials', 'Consumer', 'Financial', 'Energy', 'Real Estate', 'Food', 'Pharmaceuticals', 'Communications', 'Technology', 'Healthcare', 'Materials']
tickers_by_sectors = get_stocks_by_sector_and_price(sectors_list, max_price=500.0)
tickers = []
for _, stocks in tickers_by_sectors.items():
    tickers.extend(stocks)
prices = stock_daily_data(tickers=tickers, years_back=15, source='yahoo')
# save downloaded data to .csv file
with open(r"C:\Users\Steven\Documents\mutual_info\stock_data.csv", 'w') as f:
    prices.to_csv(f)
log_prices = preprocess_data(prices)
print(log_prices.shape)

securities = log_prices.columns
n_securities = len(securities)
log_prices.head()
# Out:
# Materials:
#
# ['LIN', 'DOW', 'APD', 'ALB', 'AVY', 'BLL', 'CE', 'CF', 'EMN', 'ECL', 'FMC', 'FCX', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PKG', 'PPG', 'SEE', 'SHW', 'VMC', 'WRK', 'CTVA']
#
# numer of stocks 24
#
# --------------------------------------------------
#
# Consumer:
#
# ['CCL', 'HD', 'MCD', 'PG', 'WMT', 'WBA', 'DIS', 'AMZN', 'CHTR', 'CMCSA', 'DISH', 'DLTR', 'EXPE', 'MAR', 'ROST', 'SBUX', 'TSLA', 'TSCO', 'ULTA', 'CL', 'F', 'GM', 'LOW', 'TGT', 'AAP', 'ABC', 'BBY', 'BWA', 'CAH', 'KMX', 'CHD', 'CLX', 'CPRT', 'CMI', 'DRI', 'DG', 'DHI', 'FBHS', 'FOXA', 'GPC', 'HAS', 'HLT', 'IPG', 'KMB', 'KR', 'LEN', 'LKQ', 'MAS', 'MCK', 'MGM', 'MHK', 'NWL', 'NWSA', 'NCLH', 'OMC', 'PHM', 'RL', 'RCL', 'SYY', 'TTWO', 'TPR', 'TJX', 'VFC', 'WHR', 'WYNN', 'YUM', 'META']
#
# numer of stocks 67
#
# --------------------------------------------------
#
# Industrials:
#
# ['MMM', 'BA', 'CAT', 'AAL', 'CSX', 'FAST', 'FISV', 'PCAR', 'PAYX', 'EMR', 'FDX', 'HON', 'RTN', 'UNP', 'UPS', 'AMD', 'ALK', 'AME', 'AOS', 'BR', 'CHRW', 'CTAS', 'DE', 'DAL', 'DOV', 'ETN', 'EFX', 'EXPD', 'FLT', 'FTV', 'GRMN', 'GPN', 'GWW', 'HII', 'ITW', 'JBHT', 'JEC', 'JCI', 'KEYS', 'MTD', 'MCO', 'MSCI', 'PH', 'PNR', 'PEG', 'PWR', 'RSG', 'RHI', 'ROK', 'ROL', 'ROP', 'SPGI', 'LUV', 'SWK', 'TEL', 'UAL', 'URI', 'WAB', 'WM', 'XYL', 'TDG']
#
# numer of stocks 61
#
# --------------------------------------------------
#
# Financial:
#
# ['AXP', 'GS', 'JPM', 'TRV', 'ALL', 'AIG', 'BAC', 'BK', 'BRK-B', 'BLK', 'COF', 'C', 'MET', 'MS', 'USB', 'WFC', 'AFL', 'AMP', 'AON', 'AJG', 'AIZ', 'CB', 'CINF', 'CFG', 'CME', 'CMA', 'DFS', 'RE', 'FIS', 'FITB', 'FRC', 'BEN', 'HIG', 'HBAN', 'ICE', 'IVZ', 'LNC', 'L', 'MTB', 'MMC', 'NDAQ', 'NTRS', 'PNC', 'PGR', 'PRU', 'RJF', 'RF', 'SCHW', 'STT', 'SIVB', 'SYF', 'TROW', 'WLTW', 'ZION', 'KEY', 'TFC', 'FDS']
#
# numer of stocks 57
#
# --------------------------------------------------
#
# Technology:
#
# ['AAPL', 'CSCO', 'IBM', 'INTC', 'MSFT', 'V', 'ATVI', 'ADBE', 'AKAM', 'GOOGL', 'ADI', 'AMAT', 'ADSK', 'ADP', 'CTSH', 'EBAY', 'EA', 'INTU', 'LRCX', 'MCHP', 'MU', 'NTAP', 'NFLX', 'NVDA', 'NXPI', 'PYPL', 'QCOM', 'STX', 'SWKS', 'TXN', 'VRSK', 'WDC', 'ACN', 'MA', 'ORCL', 'ALLE', 'APH', 'ANSS', 'APTV', 'ANET', 'AVGO', 'CDNS', 'GLW', 'DXC', 'FFIV', 'FTNT', 'IT', 'HPE', 'HPQ', 'JKHY', 'JNPR', 'KLAC', 'MSI', 'QRVO', 'CRM', 'SNA', 'SNPS', 'VRSN', 'CSGP']
#
# numer of stocks 59
#
# --------------------------------------------------
#
# Energy:
#
# ['CVX', 'XOM', 'COP', 'KMI', 'OXY', 'SLB', 'APA', 'DVN', 'FANG', 'EOG', 'HAL', 'HES', 'IFF', 'IP', 'MRO', 'MPC', 'OKE', 'PSX', 'PXD', 'VLO', 'WMB', 'ENPH']
#
# numer of stocks 22
#
# --------------------------------------------------
#
# Food:
#
# ['KO', 'KHC', 'MDLZ', 'MNST', 'MO', 'ADM', 'BF-B', 'CPB', 'CAG', 'STZ', 'GIS', 'HSY', 'HRL', 'SJM', 'K', 'LW', 'MKC', 'TSN', 'DPZ', 'TAP']
#
# numer of stocks 20
#
# --------------------------------------------------
#
# Pharmaceuticals:
#
# ['JNJ', 'MRK', 'PFE', 'AMGN', 'BIIB', 'GILD', 'INCY', 'REGN', 'VRTX', 'ABBV', 'BMY', 'LLY', 'IQV', 'ZTS', 'VTRS', 'WST', 'CRL']
#
# numer of stocks 17
#
# --------------------------------------------------
#
# Healthcare:
#
# ['UNH', 'XRAY', 'HSIC', 'ILMN', 'ISRG', 'ABT', 'CVS', 'DHR', 'MDT', 'PM', 'ABMD', 'A', 'ALGN', 'BAX', 'BDX', 'BSX', 'CNC', 'CI', 'COO', 'DVA', 'EW', 'HCA', 'HOLX', 'HUM', 'IDXX', 'LH', 'PKI', 'DGX', 'RMD', 'SYK', 'TFX', 'TMO', 'UHS', 'WAT', 'ZBH', 'MOH']
#
# numer of stocks 36
#
# --------------------------------------------------
#
# Real Estate:
#
# ['SPG', 'ARE', 'AMT', 'AVB', 'BXP', 'CBRE', 'ED', 'CCI', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'PEAK', 'HST', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'SBAC', 'UDR', 'VTR', 'VNO', 'WELL', 'WY']
#
# numer of stocks 28
#
# --------------------------------------------------
#
# total stocks:  391
# BLL: No data found, symbol may be delisted
# Download data for ticker 'BLL' FAILED!
# ValueError: ('No data found for ticker: ', 'BLL')
# FBHS: No data found, symbol may be delisted
# Download data for ticker 'FBHS' FAILED!
# ValueError: ('No data found for ticker: ', 'FBHS')
# FISV: No data found, symbol may be delisted
# Download data for ticker 'FISV' FAILED!
# ValueError: ('No data found for ticker: ', 'FISV')
# RTN: No data found, symbol may be delisted
# Download data for ticker 'RTN' FAILED!
# ValueError: ('No data found for ticker: ', 'RTN')
# JEC: No data found, symbol may be delisted
# Download data for ticker 'JEC' FAILED!
# ValueError: ('No data found for ticker: ', 'JEC')
# RE: No data found, symbol may be delisted
# Download data for ticker 'RE' FAILED!
# ValueError: ('No data found for ticker: ', 'RE')
# FRC: No data found, symbol may be delisted
# Download data for ticker 'FRC' FAILED!
# ValueError: ('No data found for ticker: ', 'FRC')
# SIVB: No data found, symbol may be delisted
# Download data for ticker 'SIVB' FAILED!
# ValueError: ('No data found for ticker: ', 'SIVB')
# WLTW: No data found, symbol may be delisted
# Download data for ticker 'WLTW' FAILED!
# ValueError: ('No data found for ticker: ', 'WLTW')
# PKI: No data found, symbol may be delisted
# Download data for ticker 'PKI' FAILED!
# ValueError: ('No data found for ticker: ', 'PKI')
#
# Number of STOCK symbols: 339
#
# (3774, 339)
#                  LIN       APD       ALB       AVY        CE        CF  \
# Date
# 2008-10-03  3.932370  3.669473  3.057711  3.300780  2.765941  2.071754
# 2008-10-06  3.932370  3.669473  3.057711  3.300780  2.765941  2.071754
# 2008-10-07  3.880148  3.637813  2.959180  3.235256  2.658152  2.020732
# 2008-10-08  3.862788  3.641473  3.003686  3.246345  2.682710  2.129764
# 2008-10-09  3.810785  3.551892  2.935947  3.162215  2.668048  2.103601
#
#                  EMN       ECL       FMC       FCX  ...       MAA       PLD  \
# Date                                                ...
# 2008-10-03  2.769078  3.575739  2.735730  2.773152  ...  3.161065  3.092682
# 2008-10-06  2.769078  3.575739  2.735730  2.773152  ...  3.161065  3.092682
# 2008-10-07  2.714010  3.543855  2.562795  2.651156  ...  3.117997  2.969105
# 2008-10-08  2.634669  3.571045  2.555902  2.747429  ...  3.146201  2.962745
# 2008-10-09  2.622904  3.480991  2.456794  2.643893  ...  3.034934  2.891700
#
#                  PSA         O      SBAC       UDR       VTR       VNO  \
# Date
# 2008-10-03  3.884441  2.384657  2.865574  2.423878  3.164261  3.426990
# 2008-10-06  3.884441  2.384657  2.865574  2.423878  3.164261  3.426990
# 2008-10-07  3.806065  2.323173  2.765202  2.372706  3.108487  3.345092
# 2008-10-08  3.816443  2.302896  2.741253  2.347102  3.089438  3.393655
# 2008-10-09  3.709594  2.251799  2.553822  2.185023  2.956640  3.269358
#
#                 WELL        WY
# Date
# 2008-10-03  3.170338  2.488077
# 2008-10-06  3.170338  2.488077
# 2008-10-07  3.140828  2.403418
# 2008-10-08  3.133103  2.421128
# 2008-10-09  3.029161  2.354181
#
# [5 rows x 339 columns]

# %% [markdown]
# ## Potential Pair Selection
#
# The mutual information of the pair is defined as:
#
# $\begin{aligned}I[X,Y] = H[X] - H[X|Y] &= H[X] + H[Y] - H[X, Y] \\
#        &= \displaystyle\sum_{x \in S_x}\displaystyle\sum_{y \in S_y}p[x,y]\log\big[\frac{p[x,y]}{p[x]p[y]}\big]\end{aligned}$
#
#   Where $p[x,y]$ is the probability mass function of $X$ and $Y$.
#
#   $p[x]$ and $p[y]$ are the marginal probability density functions of $X$ and $Y$ respectiely.
#
# Pairs with a mutual information score above an arbitrary cutoff are selected. In this example, securities in the top decile are selected.

# %%
pairs = list(combinations(securities, 2))
pairs_list = []
for pair in pairs:
    pairs_list.append(convertTuple(pair))
pairs_list[:5] # Print example
# Out:
# ['LIN-APD', 'LIN-ALB', 'LIN-AVY', 'LIN-CE', 'LIN-CF']

# %%
try:
    mutual_info_df = pd.read_csv(f'stock_mutual_info_{n_securities}.csv', index_col=0)
    print('mutual_info_df loaded')
except FileNotFoundError:
    print('Calculating mutual_info_df')
    mutual_info_df = calculate_mutual_information(pairs, pairs_list, log_prices)
    mutual_info_df.to_csv(f'stock_mutual_info_{n_securities}.csv')
# Out:
# Calculating mutual_info_df

# %% [markdown]
# ### Plot Mutual Information Scores

# %%
top_quantile = mutual_info_df.quantile(0.9)
potential_pairs = mutual_info_df[mutual_info_df >= top_quantile].dropna()
plot_potential_pairs_hist(mutual_info_df, potential_pairs)

# %% [markdown]
# # Spread Modeling
# To estimate the relationship between the potential pairs, polynomial regression is conducted. For each potential pair, a grid search over five degrees is performed by regressing the price pairs. To avoid overfitting the model, the polynomial regression that has the lowest mean squared error across a five-fold cross validation is chosen.
# From the bar chart below, the majority of the estimated relationships are linear while the remaining are nonlinear. This indicates that while a linear relationship is a valid assumption for certain pairs, the assumption does not capture certain relationships between securities in the market. The polynomial regression allows the strategy to more accurately model the spread relationships between potential pairs.

# %%
try:
    cv_models = pd.read_csv(f'stock_cv_models_{n_securities}.csv', index_col=0)
    cv_predicted = pd.read_csv(f'stock_cv_models_cv_predicted_{n_securities}.csv', index_col=0)
    cv_spreads_train = pd.read_csv(f'stock_cv_spreads_train_{n_securities}.csv', index_col=0)
    
    print('cv_models loaded')
    print('cv_predicted loaded')
    print('cv_spreads_train loaded')
except FileNotFoundError:
    print('Generating cross-validated dataframes')
    potential_pairs_tuples = []
    for pair in potential_pairs.index:
        potential_pairs_tuples.append(convertString(pair))

    cv_predicted, cv_models, cv_spreads_train = generate_cv_dataframes(potential_pairs_tuples, log_prices)
# Out:
# Generating cross-validated dataframes
# (2327, 5658)

# %% [markdown]
# ### Plot Polynomial Models

# %%
plot_cv_model_degrees(cv_models)

# %% [markdown]
# # Mean Reversion and Stationarity Testing
# Pairs trading strategies profit when the modeled spreads revert to the mean. In this section, the modeled spreads are tested rigorously for mean reversion and stationarity properties. A mean reverting spread creates profitable trading opportunities by entering long positions in the underperforming security and short positions in the outperforming security.
#
# ### Two Mean Reversion statistics:
# 1. The **Hurst exponent**, H, is used to measure the long-term memory of a time series. A value in the range of [0-0.5) indicates that a time series reverts strongly to the mean while a value of [0.5-1] indicates a time series with long-term positive autocorrelation and is likely to diverge. The Hurst exponent is calculated as:
# $\begin{aligned} \mathbb{E}\big[\frac{R(n)}{S(n)}\big] = Cn^H , n \rightarrow \infty\end{aligned}$ $R(n)$ is the range of the first $n$ cumulative deviations from the mean.
# $S(n)$ is the series of the first $n$ standard deviations.
# $\mathbb{E}$ is the expected value.
# $n$ is the number of observations in the time series.
# $C$ is a constant.
#
# 2. The **Half-Life** of a series is the amount of time it takes for a series to return to half its initial value and is defined as:
# $\begin{aligned} N(t) = N_0e^{-\lambda t} \end{aligned}$
# $N_0$ is the initial quantity of the spread that will decay.
# $N(t)$ is the quantity that still remains and has not yet decayed after a time $t$.
# $\lambda$ is a positive number called the decay constant.
# The half-life, $t_{1/2}$ is defined as:
# $\begin{aligned} t_{1/2} = \frac{ln(2)}{\lambda} \end{aligned}$
# Spreads with short half-lives indicate portfolios that revert to the mean often and create many trading opportunities.

# %%
hurst_exponents = []
for col in cv_spreads_train.columns:
    hurst_exp = calc_hurst(cv_spreads_train[col].values)
    hurst_exponents.append(hurst_exp)
    
half_lives = cv_spreads_train[cv_spreads_train.columns].apply(calc_half_life)

cv_hurst_exponents = pd.DataFrame({'hurst_exponent':hurst_exponents}, index=cv_spreads_train.columns)
cv_half_lives = pd.DataFrame({'half_life':half_lives}, index=cv_spreads_train.columns)

# %% [markdown]
# ### Stationarity Test Statistics
# Four stationarity tests are calculated for the modeled spreads:
#
# <ul>
#     <li>Augmented Dickey–Fuller: Null hypothesis that a unit root is present in the time series   </li>
#     <li>Kwiatkowski–Phillips–Schmidt–Shin: Null hypothesis that the time series is stationary   </li>
#     <li>Phillips–Perron: Null hypothesis that a time series is integrated of order 1   </li>
#     <li>Lo-Mackinlay Variance Ratio: Null hypothesis that spread follows a random walk   </li>
# </ul>
# Spreads that reject the Augmented Dickey–Fuller, Phillips–Perron, and Lo-Mackinlay tests indicate that a series is likely stationary. On the other hand, spreads that fail to reject the Kwiatkowski–Phillips–Schmidt–Shin test indicate a series is likely stationary.

# %%
cv_stationary_tests = generate_stationarity_dataframe(cv_spreads_train.columns, cv_spreads_train)
cv_test_stats = pd.concat([cv_half_lives, cv_hurst_exponents, cv_stationary_tests], axis=1)
cv_test_stats.describe()
# Out:
#          half_life  hurst_exponent   adf_t_stat   adf_p_value  kpss_t_stat  \
# count  5658.000000     5658.000000  5658.000000  5.658000e+03  5658.000000
# mean     68.670224        0.394403    -3.525389  6.640000e-02     0.632115
# std      90.786067        0.054042     1.085105  1.398929e-01     0.473489
# min       9.194341        0.125940    -8.577670  7.882338e-14     0.043932
# 25%      37.440957        0.360692    -4.229965  5.860328e-04     0.286560
# 50%      53.989722        0.397142    -3.467018  8.875677e-03     0.494564
# 75%      79.881243        0.430260    -2.796137  5.882764e-02     0.834685
# max    5450.681567        0.569666     0.407757  9.817827e-01     3.539211
#
#        kpss_p_value    pp_t_stat    pp_p_value    vr_t_stat    vr_p_value
# count   5658.000000  5658.000000  5.658000e+03  5658.000000  5.658000e+03
# mean       0.053073    -3.846831  5.281856e-02    -1.111153  3.247185e-01
# std        0.039871     1.242552  1.287569e-01     1.218504  3.014043e-01
# min        0.010000   -10.138333  8.551189e-18    -5.098668  3.420523e-07
# 25%        0.010000    -4.625817  1.157329e-04    -1.937883  5.136104e-02
# 50%        0.042891    -3.763137  3.307808e-03    -1.107405  2.315974e-01
# 75%        0.100000    -2.982329  3.657789e-02    -0.264857  5.482253e-01
# max        0.100000     0.171879  9.706396e-01     2.478295  9.998971e-01

# %% [markdown]
# ## Filter Potential Pairs
# To select spreads with desirable characteristics, the potential pairs are filtered further based on their mean reverting and stationarity statistics. Spreads with $H < 0.5$ and $1 \leq t_{1/2} \leq 252$ indicate mean reverting pairs with many tradable opportunities.
#
# Additionally, spreads that reject the Augmented Dickey–Fuller, Phillips–Perron, and Lo-Mackinlay tests at the $\alpha = 0.05$ level and fail to reject the Kwiatkowski–Phillips–Schmidt–Shin test at the $\alpha = 0.05$ level are considered stationary.

# %%
alpha_value = 0.05
mean_reversion_value = 0.5
min_half_life = 1.0
max_half_life = 63.0
cv_filtered = cv_test_stats[(cv_test_stats['kpss_p_value'] >= alpha_value) &
                            (cv_test_stats['adf_p_value'] < alpha_value) &
                            (cv_test_stats['pp_p_value'] < alpha_value) &
                            (cv_test_stats['vr_p_value'] < alpha_value) &
                            ((cv_test_stats['half_life'] >= min_half_life) & 
                            (cv_test_stats['half_life'] <= max_half_life )) &
                            (cv_test_stats['hurst_exponent'] < mean_reversion_value)]
filtered_pairs = cv_filtered.index
cv_filtered.describe()
# Out:
#         half_life  hurst_exponent  adf_t_stat   adf_p_value  kpss_t_stat  \
# count  573.000000      573.000000  573.000000  5.730000e+02   573.000000
# mean    35.619995        0.379054   -4.167125  5.562765e-03     0.279539
# std     11.572742        0.049364    0.770318  9.446296e-03     0.097425
# min     12.598577        0.198287   -7.581899  2.668252e-11     0.068611
# 25%     26.387839        0.352066   -4.670451  9.559273e-05     0.209177
# 50%     34.355353        0.382779   -4.077824  1.053580e-03     0.275278
# 75%     43.512998        0.413750   -3.552701  6.732401e-03     0.352422
# max     62.559608        0.492576   -2.873837  4.847605e-02     0.462766
#
#        kpss_p_value   pp_t_stat    pp_p_value   vr_t_stat  vr_p_value
# count    573.000000  573.000000  5.730000e+02  573.000000  573.000000
# mean       0.093468   -4.801613  1.462764e-03   -2.672306    0.015480
# std        0.013046    0.967465  3.356965e-03    0.722122    0.014899
# min        0.050101   -8.655969  4.968123e-14   -4.798344    0.000002
# 25%        0.097663   -5.387631  3.595829e-06   -3.043763    0.002336
# 50%        0.100000   -4.649450  1.046117e-04   -2.553120    0.010676
# 75%        0.100000   -4.091503  1.000324e-03   -2.213067    0.026846
# max        0.100000   -3.038086  3.148751e-02    2.372796    0.049950

# %% [markdown]
# ### Plot Filtered Pairs

# %%
plot_spreads(cv_filtered.index[:3], cv_predicted, cv_spreads_train, log_prices)

# %% [markdown]
# # Trade Signal Generation
#
# Assume the spread follows an AR(1) process, we can model the spread via the volatility model GARCH(1,1).
# The GARCH(1,1) model can capture the time-varying volatility and volatility clustering (Heteroscedasticity) that are present in the spread while also nicely provides us the boundary levels from which trading rules and signals can be derived.
#
# **Lookahead Bias** Warning:
#  We must iterate and re-fit the GARCH model to the spread per each trading interval, as opposed to using the entire spread as this would cause the GARCH model to fit to the data that it would NOT have seen in realtime trading and thus renders the backtest unrealistic.

# %% [markdown]
# ### Trade Logic:
# A trade (of 2 opposite-side positions) is opened when the spread *crosses below* the upper-boundary from above (or *crosses above* the lower-boundary from below), and we clear the positions when the spread crosses the mean.
# This strategy significantly decreases the risk and drawdown of the portfolio as it eliminates the scenarios of substantial losses where the spread significantly or completely diverges from its estimated mean.
# Also, with the advantages of modeling the spread as a GARCH process, the estimated boundary levels are very quickly adjusted to the dynamics of the spread, thus allows for large-profit opportunities where there are great dispersions from the mean.

# %% [markdown]
# ### Example:
# Lets simulate a stationary AR(1) process: $Xt ​= ϕXt − 1 ​+ ϵt$ and fit a GARCH(1,1) at each time $t$.

# %%
# Set parameters
n = 600 # number of observations
phi = 0.9 # autoregressive coefficient
mu = 0 # mean of error term
sigma = 0.5 # standard deviation of error term
x0 = 0 # initial value of time series

# Generate error term
epsilon = np.random.normal(mu, sigma, n)

# Initialize time series
x = pd.Series(np.zeros(n))

# Set initial value
x[0] = x0

# Set training window 
window = 252 * 2 

# Generate the time series & fit GARCH model
vols = np.array([])
mean = []
for i in range(1, n):
    x[i] = phi * x[i-1] + epsilon[i]
    # fit the GARCH(1,1) model to the rolling time series
    if i >= window:
        model = arch_model(x[i-window:i], rescale=False)
        model.distribution = StudentsT(seed=42)
        model.mean = HARX(x[i-window:i][1:].values, x[i-window:i][:-1].values.reshape(-1, 1), lags=1)
        model.volatility = GARCH(p=1, q=1)
        fitted_model = model.fit(disp=False)
        con_vol = fitted_model.conditional_volatility.iloc[-1]
        mu = fitted_model.params.mu
        vols = np.append(vols, con_vol)
        mean.append(mu)

# Plot 
idx = x[window:].index
plt.figure(figsize=(15, 8))
plt.plot(x[window:], label='Spread')
plt.plot(idx,vols, color='red', label='UPPER Conditional Volatility')
plt.plot(idx,-vols, color='green', label='LOWER Conditional Volatility')
plt.plot(idx, mean, color='black', label='Estimated Mean', linestyle='--')
plt.legend()
plt.title('Rolling Modeled Spread')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # Backtest
# The formation period which best mutual information pairs are selected is 2 years.
# The trading period is carried out in the next 3 months/ 1 quarter.
# To make the backtest more realistic, trading costs of 0.25% per entry or 0.5% per trade is added.
# **1:20 Leverage** is proposed in this strategy.

# %%
train_window = 252*2  # 2 years
trade_window = 63 # 1 quarter 
backtest_result = {}
for i in range(train_window, len(prices)-trade_window, trade_window):
    train = prices.iloc[i-train_window:i]
    test = prices.iloc[i:i+trade_window+1]
    best_pairs = []
    best_models = []
    print("\n#########################################################################\n")
    print(f"Formation Period: {train.index[0]} - {train.index[-1]}")
    for sector, stocks in tickers_by_sectors.items():
    # Select the top 90 percentile during the training formation
        result_dict = formation_stock(train, sector, stocks, top_pctile=0.9)
        if result_dict is not None and len(result_dict) > 0:
            # get best_pairs, best_models, half_lives
            best_pairs.extend(list(result_dict.values())[0])
            best_models.extend(list(result_dict.values())[1])
    print(f"\nTotal Pairs: {len(best_pairs)}")
    # Backtest
    for pair, model in zip(best_pairs, best_models):
        log_train = preprocess_data(train)
        train_spread = calc_norm_spread(pair, model, log_train)
        log_test = preprocess_data(test)
        test_spread = calc_norm_spread(pair, model, log_test)
        S1 = test[pair[0]]
        S2 = test[pair[1]]
        result = backtest_stock(S1, S2, train_spread, test_spread, fee=0.0025) # round-trip cost: 0.5%
        # append backtest results
        pair_name = f'{pair[0]}-{pair[1]}'
        if pair_name not in backtest_result.keys():
            backtest_result[pair_name] = []
        backtest_result[pair_name].append(result)
# Out:
# #########################################################################
#
# Formation Period: 2008-10-03 - 2010-10-04
#
# Found 2 pairs in MATERIALS:
# [('EMN', 'ECL'), ('EMN', 'PPG')]
#
# Found 6 pairs in CONSUMER:
# [('MAR', 'RCL'), ('SBUX', 'RL'), ('DIS', 'WYNN'), ('MAR', 'RL'), ('F', 'ABC'), ('SBUX', 'TPR')]
#
# Found 2 pairs in INDUSTRIALS:
# [('EMR', 'MTD'), ('DOV', 'ROK')]
#
# Found 4 pairs in FINANCIAL:
# [('L', 'PRU'), ('PGR', 'FDS'), ('COF', 'AFL'), ('DFS', 'BEN')]
#
# Found 7 pairs in TECHNOLOGY:
# [('SWKS', 'WDC'), ('WDC', 'DXC'), ('NTAP', 'WDC'), ('NTAP', 'SWKS'), ('AAPL', 'NTAP'), ('CTSH', 'NTAP'), ('NTAP', 'FFIV')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('RMD', 'WAT')]
#
# Found 2 pairs in REAL ESTATE:
# [('AVB', 'HST'), ('DLR', 'MAA')]
#
# Total Pairs: 24
#
# #########################################################################
#
# Formation Period: 2009-01-05 - 2011-01-03
#
# Found 3 pairs in MATERIALS:
# [('EMN', 'FMC'), ('LIN', 'EMN'), ('FMC', 'PPG')]
#
# Found 3 pairs in CONSUMER:
# [('F', 'TGT'), ('TSCO', 'ULTA'), ('CMI', 'TPR')]
#
# Found 9 pairs in INDUSTRIALS:
# [('MTD', 'PH'), ('EMR', 'UNP'), ('HON', 'DOV'), ('CSX', 'HON'), ('UNP', 'DE'), ('CSX', 'DOV'), ('CSX', 'ETN'), ('EMR', 'ETN'), ('ETN', 'PH')]
#
# Found 4 pairs in FINANCIAL:
# [('COF', 'LNC'), ('PGR', 'PRU'), ('DFS', 'BEN'), ('AMP', 'TROW')]
#
# Found 8 pairs in TECHNOLOGY:
# [('CTSH', 'TXN'), ('IBM', 'TXN'), ('NTAP', 'APH'), ('NTAP', 'SWKS'), ('CTSH', 'SWKS'), ('AAPL', 'NTAP'), ('CTSH', 'NTAP'), ('AAPL', 'IBM')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 2 pairs in REAL ESTATE:
# [('AVB', 'VTR'), ('SPG', 'O')]
#
# Total Pairs: 29
#
# #########################################################################
#
# Formation Period: 2009-04-06 - 2011-04-04
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 8 pairs in CONSUMER:
# [('SBUX', 'TJX'), ('ULTA', 'TJX'), ('DLTR', 'SBUX'), ('ULTA', 'RL'), ('SBUX', 'RL'), ('DLTR', 'WYNN'), ('ROST', 'TJX'), ('SBUX', 'ABC')]
#
# Found 5 pairs in INDUSTRIALS:
# [('CAT', 'CSX'), ('MTD', 'PH'), ('MTD', 'ROL'), ('UNP', 'ETN'), ('CAT', 'ETN')]
#
# Found 2 pairs in FINANCIAL:
# [('DFS', 'L'), ('DFS', 'MMC')]
#
# Found 6 pairs in TECHNOLOGY:
# [('CTSH', 'TXN'), ('IBM', 'ORCL'), ('IBM', 'ADP'), ('CTSH', 'SNA'), ('NTAP', 'FFIV'), ('FFIV', 'CRM')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 1 pairs in REAL ESTATE:
# [('EXR', 'PSA')]
#
# Total Pairs: 22
#
# #########################################################################
#
# Formation Period: 2009-07-07 - 2011-07-05
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('ABC', 'TJX'), ('TSCO', 'VFC'), ('SBUX', 'RL'), ('DLTR', 'SBUX'), ('TSCO', 'ULTA')]
#
# Found 2 pairs in INDUSTRIALS:
# [('ROP', 'SWK'), ('ROL', 'ROP')]
#
# Found 3 pairs in FINANCIAL:
# [('AJG', 'TROW'), ('DFS', 'L'), ('TRV', 'L')]
#
# Found 3 pairs in TECHNOLOGY:
# [('SNA', 'CSGP'), ('IBM', 'ADP'), ('NTAP', 'FFIV')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 1 pairs in FOOD:
# [('HRL', 'MKC')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('COO', 'WAT')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2009-10-05 - 2011-10-03
#
# Found 3 pairs in MATERIALS:
# [('EMN', 'PPG'), ('EMN', 'FMC'), ('FMC', 'PPG')]
#
# Found 4 pairs in CONSUMER:
# [('CHD', 'TJX'), ('ABC', 'TJX'), ('DLTR', 'TJX'), ('AMZN', 'RL')]
#
# Found 2 pairs in INDUSTRIALS:
# [('PH', 'URI'), ('CAT', 'UNP')]
#
# Found 2 pairs in FINANCIAL:
# [('AMP', 'L'), ('AMP', 'CINF')]
#
# Found 8 pairs in TECHNOLOGY:
# [('IBM', 'JKHY'), ('ADP', 'MSI'), ('ADI', 'ORCL'), ('IBM', 'ORCL'), ('VRSN', 'CSGP'), ('IT', 'MSI'), ('ADI', 'TXN'), ('IBM', 'ACN')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 1 pairs in FOOD:
# [('MNST', 'DPZ')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 3 pairs in REAL ESTATE:
# [('EXR', 'PSA'), ('SPG', 'EXR'), ('SPG', 'PSA')]
#
# Total Pairs: 23
#
# #########################################################################
#
# Formation Period: 2010-01-05 - 2012-01-03
#
# Found 1 pairs in MATERIALS:
# [('ALB', 'EMN')]
#
# Found 13 pairs in CONSUMER:
# [('ULTA', 'CLX'), ('TSCO', 'CLX'), ('ROST', 'ABC'), ('TSCO', 'CHD'), ('ABC', 'CAH'), ('ROST', 'CHD'), ('SBUX', 'RL'), ('SBUX', 'CHD'), ('ROST', 'GPC'), ('DLTR', 'VFC'), ('MCD', 'YUM'), ('ROST', 'TSCO'), ('ROST', 'TJX')]
#
# Found 7 pairs in INDUSTRIALS:
# [('ALK', 'ROP'), ('ROL', 'ROP'), ('HON', 'URI'), ('CTAS', 'WAB'), ('UNP', 'ALK'), ('UNP', 'AME'), ('ETN', 'PH')]
#
# Found 3 pairs in FINANCIAL:
# [('MMC', 'NDAQ'), ('AJG', 'FDS'), ('HIG', 'LNC')]
#
# Found 5 pairs in TECHNOLOGY:
# [('IBM', 'ORCL'), ('CTSH', 'CRM'), ('VRSN', 'CSGP'), ('IBM', 'CDNS'), ('IBM', 'ADP')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('EW', 'LH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 30
#
# #########################################################################
#
# Formation Period: 2010-04-07 - 2012-04-03
#
# Found 2 pairs in MATERIALS:
# [('ALB', 'EMN'), ('FMC', 'PPG')]
#
# Found 12 pairs in CONSUMER:
# [('KMB', 'TJX'), ('ROST', 'KMB'), ('MCD', 'KMB'), ('DLTR', 'KMB'), ('DLTR', 'TJX'), ('DLTR', 'RL'), ('DLTR', 'AAP'), ('TSCO', 'CHD'), ('ROST', 'CHD'), ('SBUX', 'RL'), ('MCD', 'DLTR'), ('ROST', 'TJX')]
#
# Found 2 pairs in INDUSTRIALS:
# [('ETN', 'PH'), ('UPS', 'URI')]
#
# Found 1 pairs in FINANCIAL:
# [('FITB', 'PNC')]
#
# Found 4 pairs in TECHNOLOGY:
# [('VRSN', 'CSGP'), ('CDNS', 'JKHY'), ('IBM', 'ACN'), ('JKHY', 'KLAC')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('DVA', 'LH'), ('HSIC', 'DVA')]
#
# Found 1 pairs in REAL ESTATE:
# [('SPG', 'AMT')]
#
# Total Pairs: 24
#
# #########################################################################
#
# Formation Period: 2010-07-07 - 2012-07-03
#
# Found 1 pairs in MATERIALS:
# [('EMN', 'PKG')]
#
# Found 5 pairs in CONSUMER:
# [('ULTA', 'YUM'), ('TJX', 'VFC'), ('TSCO', 'GPC'), ('ROST', 'SBUX'), ('TSCO', 'ULTA')]
#
# Found 3 pairs in INDUSTRIALS:
# [('DOV', 'PH'), ('UPS', 'URI'), ('UNP', 'CTAS')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 4 pairs in TECHNOLOGY:
# [('CDNS', 'KLAC'), ('CDNS', 'IT'), ('INTU', 'QCOM'), ('JKHY', 'KLAC')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('HSIC', 'DVA')]
#
# Found 1 pairs in REAL ESTATE:
# [('SPG', 'AMT')]
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2010-10-05 - 2012-10-02
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('ROST', 'CLX'), ('TSCO', 'YUM'), ('TSCO', 'GPC'), ('CHD', 'KMB')]
#
# Found 0 pairs in INDUSTRIALS:
# []
#
# Found 2 pairs in FINANCIAL:
# [('AXP', 'USB'), ('GS', 'MS')]
#
# Found 1 pairs in TECHNOLOGY:
# [('ANSS', 'CDNS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('PFE', 'AMGN')]
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 8
#
# #########################################################################
#
# Formation Period: 2011-01-04 - 2013-01-04
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('ROST', 'SBUX'), ('TSCO', 'ULTA')]
#
# Found 3 pairs in INDUSTRIALS:
# [('AOS', 'PNR'), ('AOS', 'PWR'), ('EFX', 'PNR')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 4 pairs in TECHNOLOGY:
# [('ADP', 'MSI'), ('CDNS', 'MSI'), ('V', 'MSI'), ('V', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 6 pairs in REAL ESTATE:
# [('AMT', 'EQIX'), ('SBAC', 'VTR'), ('AMT', 'O'), ('AMT', 'CCI'), ('SPG', 'FRT'), ('SPG', 'PSA')]
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2011-04-05 - 2013-04-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('ROST', 'SBUX'), ('HD', 'CLX'), ('LKQ', 'TJX'), ('KMB', 'TJX'), ('LEN', 'PHM')]
#
# Found 1 pairs in INDUSTRIALS:
# [('AME', 'AOS')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 5 pairs in TECHNOLOGY:
# [('INTU', 'CDNS'), ('APH', 'MSI'), ('ACN', 'MSI'), ('V', 'MSI'), ('MA', 'MSI')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('CVS', 'PM'), ('COO', 'TFX')]
#
# Found 3 pairs in REAL ESTATE:
# [('AMT', 'WELL'), ('AMT', 'EXR'), ('PEAK', 'VTR')]
#
# Total Pairs: 16
#
# #########################################################################
#
# Formation Period: 2011-07-06 - 2013-07-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('HD', 'CLX'), ('TGT', 'TJX'), ('CMCSA', 'CLX'), ('CHD', 'TJX'), ('HD', 'CL')]
#
# Found 0 pairs in INDUSTRIALS:
# []
#
# Found 2 pairs in FINANCIAL:
# [('WFC', 'DFS'), ('HBAN', 'RF')]
#
# Found 1 pairs in TECHNOLOGY:
# [('ACN', 'APH')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('AMGN', 'GILD')]
#
# Found 2 pairs in HEALTHCARE:
# [('MDT', 'DVA'), ('DVA', 'TFX')]
#
# Found 5 pairs in REAL ESTATE:
# [('CCI', 'EQIX'), ('AMT', 'PEAK'), ('CCI', 'FRT'), ('AMT', 'FRT'), ('AMT', 'VTR')]
#
# Total Pairs: 16
#
# #########################################################################
#
# Formation Period: 2011-10-04 - 2013-10-04
#
# Found 1 pairs in MATERIALS:
# [('ECL', 'FMC')]
#
# Found 2 pairs in CONSUMER:
# [('DISH', 'LKQ'), ('CL', 'KMB')]
#
# Found 2 pairs in INDUSTRIALS:
# [('RSG', 'WM'), ('MMM', 'UNP')]
#
# Found 4 pairs in FINANCIAL:
# [('FITB', 'HBAN'), ('AJG', 'FITB'), ('AMP', 'IVZ'), ('ALL', 'BRK-B')]
#
# Found 5 pairs in TECHNOLOGY:
# [('ADP', 'WDC'), ('ADBE', 'WDC'), ('ADBE', 'STX'), ('ADBE', 'ADP'), ('V', 'ADP')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 2 pairs in REAL ESTATE:
# [('AMT', 'FRT'), ('CCI', 'WY')]
#
# Total Pairs: 16
#
# #########################################################################
#
# Formation Period: 2012-01-04 - 2014-01-06
#
# Found 3 pairs in MATERIALS:
# [('PPG', 'SHW'), ('ECL', 'PPG'), ('PKG', 'PPG')]
#
# Found 4 pairs in CONSUMER:
# [('LOW', 'MHK'), ('DISH', 'KR'), ('DISH', 'LOW'), ('CL', 'CLX')]
#
# Found 4 pairs in INDUSTRIALS:
# [('PNR', 'TDG'), ('HON', 'DOV'), ('EMR', 'DOV'), ('MMM', 'HON')]
#
# Found 2 pairs in FINANCIAL:
# [('BK', 'TROW'), ('BK', 'LNC')]
#
# Found 3 pairs in TECHNOLOGY:
# [('ADP', 'WDC'), ('V', 'ADP'), ('ADP', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('DHR', 'SYK'), ('MDT', 'BSX')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 18
#
# #########################################################################
#
# Formation Period: 2012-04-04 - 2014-04-07
#
# Found 1 pairs in MATERIALS:
# [('ECL', 'PKG')]
#
# Found 2 pairs in CONSUMER:
# [('CL', 'CLX'), ('DISH', 'ABC')]
#
# Found 2 pairs in INDUSTRIALS:
# [('JCI', 'TEL'), ('CTAS', 'JCI')]
#
# Found 3 pairs in FINANCIAL:
# [('CMA', 'PNC'), ('CMA', 'HBAN'), ('MS', 'HIG')]
#
# Found 6 pairs in TECHNOLOGY:
# [('V', 'APH'), ('ADP', 'MA'), ('V', 'GOOGL'), ('V', 'JKHY'), ('V', 'SNA'), ('ADP', 'JKHY')]
#
# Found 1 pairs in ENERGY:
# [('HAL', 'IFF')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('VTRS', 'CRL')]
#
# Found 4 pairs in HEALTHCARE:
# [('MDT', 'BSX'), ('HSIC', 'BSX'), ('HSIC', 'DHR'), ('SYK', 'ZBH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 20
#
# #########################################################################
#
# Formation Period: 2012-07-05 - 2014-07-08
#
# Found 5 pairs in MATERIALS:
# [('PPG', 'SEE'), ('APD', 'PPG'), ('AVY', 'PKG'), ('APD', 'PKG'), ('PKG', 'PPG')]
#
# Found 6 pairs in CONSUMER:
# [('PG', 'CLX'), ('ABC', 'CLX'), ('HD', 'WHR'), ('WBA', 'CL'), ('LOW', 'MHK'), ('WBA', 'AAP')]
#
# Found 1 pairs in INDUSTRIALS:
# [('CTAS', 'JCI')]
#
# Found 4 pairs in FINANCIAL:
# [('CMA', 'LNC'), ('CMA', 'STT'), ('HBAN', 'SCHW'), ('CMA', 'HBAN')]
#
# Found 5 pairs in TECHNOLOGY:
# [('JKHY', 'MSI'), ('V', 'ADBE'), ('V', 'JKHY'), ('AMAT', 'LRCX'), ('ADP', 'JKHY')]
#
# Found 1 pairs in ENERGY:
# [('HAL', 'IFF')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('MDT', 'BSX'), ('DHR', 'ZBH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 24
#
# #########################################################################
#
# Formation Period: 2012-10-03 - 2014-10-06
#
# Found 2 pairs in MATERIALS:
# [('PPG', 'SEE'), ('APD', 'PKG')]
#
# Found 3 pairs in CONSUMER:
# [('WBA', 'WYNN'), ('CL', 'KMB'), ('DISH', 'KR')]
#
# Found 2 pairs in INDUSTRIALS:
# [('AAL', 'DAL'), ('DAL', 'TEL')]
#
# Found 3 pairs in FINANCIAL:
# [('AIZ', 'CMA'), ('BK', 'LNC'), ('MET', 'PRU')]
#
# Found 5 pairs in TECHNOLOGY:
# [('MCHP', 'HPQ'), ('NFLX', 'KLAC'), ('TXN', 'HPQ'), ('LRCX', 'WDC'), ('MA', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 4 pairs in HEALTHCARE:
# [('UNH', 'HUM'), ('BDX', 'SYK'), ('BDX', 'ZBH'), ('BDX', 'TMO')]
#
# Found 1 pairs in REAL ESTATE:
# [('EXR', 'PSA')]
#
# Total Pairs: 20
#
# #########################################################################
#
# Formation Period: 2013-01-07 - 2015-01-06
#
# Found 2 pairs in MATERIALS:
# [('APD', 'PPG'), ('PKG', 'PPG')]
#
# Found 5 pairs in CONSUMER:
# [('CHD', 'SYY'), ('PG', 'CLX'), ('DIS', 'SYY'), ('DLTR', 'ROST'), ('ABC', 'GPC')]
#
# Found 6 pairs in INDUSTRIALS:
# [('EFX', 'LUV'), ('CTAS', 'ROP'), ('DAL', 'TEL'), ('DAL', 'TDG'), ('FDX', 'CTAS'), ('BR', 'CTAS')]
#
# Found 4 pairs in FINANCIAL:
# [('BK', 'IVZ'), ('MS', 'SCHW'), ('AON', 'AIZ'), ('MET', 'PRU')]
#
# Found 3 pairs in TECHNOLOGY:
# [('V', 'JKHY'), ('AMAT', 'KLAC'), ('AMAT', 'LRCX')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 1 pairs in REAL ESTATE:
# [('BXP', 'FRT')]
#
# Total Pairs: 21
#
# #########################################################################
#
# Formation Period: 2013-04-09 - 2015-04-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('MAR', 'SYY'), ('RCL', 'SYY'), ('MAR', 'TTWO'), ('LOW', 'TJX')]
#
# Found 6 pairs in INDUSTRIALS:
# [('HON', 'DAL'), ('HON', 'BR'), ('AAL', 'ALK'), ('CTAS', 'ROP'), ('ALK', 'TDG'), ('FDX', 'CTAS')]
#
# Found 1 pairs in FINANCIAL:
# [('BK', 'MS')]
#
# Found 3 pairs in TECHNOLOGY:
# [('NVDA', 'APH'), ('V', 'JKHY'), ('AMAT', 'LRCX')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 1 pairs in REAL ESTATE:
# [('BXP', 'EQR')]
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2013-07-09 - 2015-07-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 3 pairs in CONSUMER:
# [('DLTR', 'ROST'), ('CLX', 'NWL'), ('MAR', 'TTWO')]
#
# Found 5 pairs in INDUSTRIALS:
# [('MCO', 'ROP'), ('EFX', 'ROP'), ('MCO', 'TDG'), ('MCO', 'RHI'), ('HON', 'GPN')]
#
# Found 5 pairs in FINANCIAL:
# [('HIG', 'HBAN'), ('HBAN', 'NDAQ'), ('MS', 'SCHW'), ('PNC', 'SCHW'), ('HIG', 'NDAQ')]
#
# Found 2 pairs in TECHNOLOGY:
# [('ADP', 'CTSH'), ('V', 'SNPS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('INCY', 'BMY')]
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 3 pairs in REAL ESTATE:
# [('SPG', 'KIM'), ('ARE', 'BXP'), ('SPG', 'BXP')]
#
# Total Pairs: 19
#
# #########################################################################
#
# Formation Period: 2013-10-07 - 2015-10-06
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 0 pairs in CONSUMER:
# []
#
# Found 5 pairs in INDUSTRIALS:
# [('EFX', 'RSG'), ('MCO', 'ROP'), ('MCO', 'TDG'), ('CTAS', 'ROP'), ('CTAS', 'MCO')]
#
# Found 2 pairs in FINANCIAL:
# [('AON', 'SCHW'), ('WFC', 'NTRS')]
#
# Found 5 pairs in TECHNOLOGY:
# [('V', 'CTSH'), ('ACN', 'MA'), ('MA', 'JKHY'), ('V', 'JKHY'), ('V', 'SNPS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('SYK', 'TFX')]
#
# Found 1 pairs in REAL ESTATE:
# [('SPG', 'FRT')]
#
# Total Pairs: 14
#
# #########################################################################
#
# Formation Period: 2014-01-07 - 2016-01-06
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 6 pairs in CONSUMER:
# [('ULTA', 'DRI'), ('ROST', 'DRI'), ('ABC', 'DRI'), ('CCL', 'SBUX'), ('ROST', 'LOW'), ('HD', 'SBUX')]
#
# Found 4 pairs in INDUSTRIALS:
# [('GPN', 'RHI'), ('EFX', 'SWK'), ('EFX', 'ROP'), ('CTAS', 'EFX')]
#
# Found 2 pairs in FINANCIAL:
# [('NDAQ', 'PGR'), ('WFC', 'NTRS')]
#
# Found 0 pairs in TECHNOLOGY:
# []
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('MDT', 'DGX')]
#
# Found 2 pairs in REAL ESTATE:
# [('AVB', 'ESS'), ('EQR', 'ESS')]
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2014-04-08 - 2016-04-07
#
# Found 2 pairs in MATERIALS:
# [('FCX', 'NUE'), ('FCX', 'MLM')]
#
# Found 6 pairs in CONSUMER:
# [('NWL', 'RCL'), ('CHD', 'KR'), ('ROST', 'DRI'), ('CLX', 'TTWO'), ('ULTA', 'DRI'), ('HD', 'SBUX')]
#
# Found 4 pairs in INDUSTRIALS:
# [('CAT', 'PH'), ('AOS', 'MTD'), ('EFX', 'SWK'), ('BR', 'CTAS')]
#
# Found 1 pairs in FINANCIAL:
# [('PNC', 'SCHW')]
#
# Found 4 pairs in TECHNOLOGY:
# [('CTSH', 'SNPS'), ('MA', 'SNPS'), ('NTAP', 'HPQ'), ('NVDA', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('CNC', 'DGX'), ('CVS', 'MOH')]
#
# Found 5 pairs in REAL ESTATE:
# [('AVB', 'FRT'), ('AVB', 'ESS'), ('EXR', 'MAA'), ('SPG', 'FRT'), ('AVB', 'EQR')]
#
# Total Pairs: 24
#
# #########################################################################
#
# Formation Period: 2014-07-09 - 2016-07-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('ROST', 'DRI'), ('HD', 'SBUX'), ('HD', 'TJX'), ('ULTA', 'DRI'), ('HD', 'ROST')]
#
# Found 4 pairs in INDUSTRIALS:
# [('CAT', 'GRMN'), ('BR', 'PEG'), ('GPN', 'MTD'), ('ETN', 'PH')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 2 pairs in TECHNOLOGY:
# [('V', 'CRM'), ('NVDA', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 2 pairs in REAL ESTATE:
# [('EQR', 'ESS'), ('EXR', 'MAA')]
#
# Total Pairs: 13
#
# #########################################################################
#
# Formation Period: 2014-10-07 - 2016-10-05
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('CLX', 'TJX'), ('ULTA', 'DRI'), ('HD', 'SBUX'), ('BWA', 'RL')]
#
# Found 3 pairs in INDUSTRIALS:
# [('ETN', 'PH'), ('MTD', 'TDG'), ('HON', 'MTD')]
#
# Found 1 pairs in FINANCIAL:
# [('BAC', 'PRU')]
#
# Found 2 pairs in TECHNOLOGY:
# [('GOOGL', 'STX'), ('NVDA', 'JKHY')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('LH', 'DGX'), ('MDT', 'DGX')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 12
#
# #########################################################################
#
# Formation Period: 2015-01-07 - 2017-01-05
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('MCD', 'IPG'), ('HD', 'TJX')]
#
# Found 1 pairs in INDUSTRIALS:
# [('CAT', 'PH')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 1 pairs in TECHNOLOGY:
# [('JKHY', 'KLAC')]
#
# Found 1 pairs in ENERGY:
# [('SLB', 'IP')]
#
# Found 1 pairs in FOOD:
# [('MO', 'TSN')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 6
#
# #########################################################################
#
# Formation Period: 2015-04-09 - 2017-04-06
#
# Found 1 pairs in MATERIALS:
# [('ALB', 'NEM')]
#
# Found 2 pairs in CONSUMER:
# [('HD', 'TJX'), ('ULTA', 'CPRT')]
#
# Found 2 pairs in INDUSTRIALS:
# [('PCAR', 'PWR'), ('AMD', 'MTD')]
#
# Found 2 pairs in FINANCIAL:
# [('BAC', 'SCHW'), ('MS', 'LNC')]
#
# Found 1 pairs in TECHNOLOGY:
# [('STX', 'WDC')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 1 pairs in FOOD:
# [('STZ', 'K')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('IDXX', 'DGX')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 10
#
# #########################################################################
#
# Formation Period: 2015-07-09 - 2017-07-07
#
# Found 1 pairs in MATERIALS:
# [('APD', 'NUE')]
#
# Found 5 pairs in CONSUMER:
# [('MAS', 'OMC'), ('CHD', 'TPR'), ('CPRT', 'DRI'), ('CMCSA', 'DRI'), ('CMI', 'DRI')]
#
# Found 2 pairs in INDUSTRIALS:
# [('CAT', 'PH'), ('RSG', 'WM')]
#
# Found 2 pairs in FINANCIAL:
# [('BAC', 'SCHW'), ('PRU', 'SCHW')]
#
# Found 2 pairs in TECHNOLOGY:
# [('LRCX', 'APH'), ('LRCX', 'GLW')]
#
# Found 1 pairs in ENERGY:
# [('EOG', 'HAL')]
#
# Found 1 pairs in FOOD:
# [('MO', 'TSN')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 3 pairs in HEALTHCARE:
# [('A', 'BAX'), ('BSX', 'WAT'), ('A', 'ALGN')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 17
#
# #########################################################################
#
# Formation Period: 2015-10-07 - 2017-10-05
#
# Found 2 pairs in MATERIALS:
# [('LIN', 'APD'), ('CE', 'EMN')]
#
# Found 2 pairs in CONSUMER:
# [('CMCSA', 'RCL'), ('CPRT', 'MAS')]
#
# Found 0 pairs in INDUSTRIALS:
# []
#
# Found 1 pairs in FINANCIAL:
# [('PRU', 'SCHW')]
#
# Found 6 pairs in TECHNOLOGY:
# [('CDNS', 'GLW'), ('INTU', 'JKHY'), ('LRCX', 'CDNS'), ('MCHP', 'NVDA'), ('AMAT', 'SNPS'), ('MCHP', 'SNPS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 2 pairs in FOOD:
# [('MO', 'TSN'), ('GIS', 'K')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 4 pairs in HEALTHCARE:
# [('A', 'IDXX'), ('A', 'DGX'), ('A', 'BAX'), ('ALGN', 'DGX')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 17
#
# #########################################################################
#
# Formation Period: 2016-01-07 - 2018-01-05
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 0 pairs in CONSUMER:
# []
#
# Found 2 pairs in INDUSTRIALS:
# [('BA', 'DE'), ('PH', 'ROK')]
#
# Found 1 pairs in FINANCIAL:
# [('LNC', 'RJF')]
#
# Found 9 pairs in TECHNOLOGY:
# [('INTU', 'CDNS'), ('INTU', 'SNPS'), ('INTU', 'JKHY'), ('MCHP', 'CDNS'), ('AMAT', 'CDNS'), ('V', 'MA'), ('MCHP', 'SNPS'), ('MCHP', 'NVDA'), ('AMAT', 'NVDA')]
#
# Found 1 pairs in ENERGY:
# [('DVN', 'MRO')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 2 pairs in HEALTHCARE:
# [('A', 'DGX'), ('A', 'ALGN')]
#
# Found 1 pairs in REAL ESTATE:
# [('AMT', 'PLD')]
#
# Total Pairs: 16
#
# #########################################################################
#
# Formation Period: 2016-04-08 - 2018-04-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('CCL', 'DRI'), ('CCL', 'RCL')]
#
# Found 0 pairs in INDUSTRIALS:
# []
#
# Found 1 pairs in FINANCIAL:
# [('BRK-B', 'PNC')]
#
# Found 2 pairs in TECHNOLOGY:
# [('MA', 'APH'), ('MSFT', 'MA')]
#
# Found 1 pairs in ENERGY:
# [('CVX', 'OKE')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('A', 'ALGN')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 7
#
# #########################################################################
#
# Formation Period: 2016-07-08 - 2018-07-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('MCD', 'MAS'), ('CCL', 'RCL')]
#
# Found 3 pairs in INDUSTRIALS:
# [('EXPD', 'ITW'), ('CTAS', 'SPGI'), ('BA', 'ROK')]
#
# Found 1 pairs in FINANCIAL:
# [('JPM', 'PNC')]
#
# Found 0 pairs in TECHNOLOGY:
# []
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('ABT', 'TMO')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 7
#
# #########################################################################
#
# Formation Period: 2016-10-06 - 2018-10-05
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('BBY', 'TJX'), ('CPRT', 'RL'), ('HD', 'WYNN'), ('AMZN', 'CPRT')]
#
# Found 3 pairs in INDUSTRIALS:
# [('MMM', 'ITW'), ('CTAS', 'EXPD'), ('CTAS', 'SPGI')]
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 1 pairs in TECHNOLOGY:
# [('MSFT', 'MA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('ABT', 'TMO')]
#
# Found 3 pairs in REAL ESTATE:
# [('EXR', 'WY'), ('DLR', 'UDR'), ('CCI', 'PLD')]
#
# Total Pairs: 12
#
# #########################################################################
#
# Formation Period: 2017-01-06 - 2019-01-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 0 pairs in CONSUMER:
# []
#
# Found 5 pairs in INDUSTRIALS:
# [('UNP', 'EXPD'), ('CTAS', 'EXPD'), ('GPN', 'ROP'), ('GPN', 'MCO'), ('BR', 'CTAS')]
#
# Found 3 pairs in FINANCIAL:
# [('AXP', 'ICE'), ('AXP', 'FIS'), ('AXP', 'FDS')]
#
# Found 6 pairs in TECHNOLOGY:
# [('V', 'FFIV'), ('MSFT', 'FFIV'), ('MA', 'MSI'), ('V', 'MSI'), ('V', 'CRM'), ('MSFT', 'MA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('ILMN', 'RMD')]
#
# Found 2 pairs in REAL ESTATE:
# [('CBRE', 'HST'), ('AVB', 'WELL')]
#
# Total Pairs: 17
#
# #########################################################################
#
# Formation Period: 2017-04-07 - 2019-04-09
#
# Found 1 pairs in MATERIALS:
# [('MLM', 'VMC')]
#
# Found 5 pairs in CONSUMER:
# [('CHD', 'MCK'), ('DHI', 'PHM'), ('CPRT', 'VFC'), ('AMZN', 'VFC'), ('AMZN', 'CPRT')]
#
# Found 3 pairs in INDUSTRIALS:
# [('UNP', 'EXPD'), ('CTAS', 'EXPD'), ('HON', 'AME')]
#
# Found 1 pairs in FINANCIAL:
# [('JPM', 'TFC')]
#
# Found 5 pairs in TECHNOLOGY:
# [('CSCO', 'MSI'), ('MA', 'MSI'), ('V', 'CRM'), ('MSFT', 'INTU'), ('MSFT', 'MA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 1 pairs in REAL ESTATE:
# [('AMT', 'O')]
#
# Total Pairs: 16
#
# #########################################################################
#
# Formation Period: 2017-07-10 - 2019-07-10
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 3 pairs in CONSUMER:
# [('CPRT', 'VFC'), ('ROST', 'VFC'), ('TSCO', 'ULTA')]
#
# Found 4 pairs in INDUSTRIALS:
# [('PH', 'ROK'), ('HON', 'AME'), ('UNP', 'ROP'), ('MSCI', 'ROP')]
#
# Found 2 pairs in FINANCIAL:
# [('AFL', 'FDS'), ('FIS', 'FDS')]
#
# Found 4 pairs in TECHNOLOGY:
# [('ADBE', 'ADSK'), ('MA', 'MSI'), ('V', 'MSI'), ('MSFT', 'MA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 13
#
# #########################################################################
#
# Formation Period: 2017-10-06 - 2019-10-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 1 pairs in CONSUMER:
# [('MCD', 'SBUX')]
#
# Found 1 pairs in INDUSTRIALS:
# [('CSX', 'EXPD')]
#
# Found 3 pairs in FINANCIAL:
# [('ICE', 'MMC'), ('AFL', 'FDS'), ('AON', 'CINF')]
#
# Found 3 pairs in TECHNOLOGY:
# [('MSI', 'CSGP'), ('V', 'ADBE'), ('V', 'MA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('BSX', 'COO')]
#
# Found 2 pairs in REAL ESTATE:
# [('AMT', 'UDR'), ('PEAK', 'O')]
#
# Total Pairs: 11
#
# #########################################################################
#
# Formation Period: 2018-01-08 - 2020-01-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('PG', 'CLX'), ('PG', 'SBUX')]
#
# Found 1 pairs in INDUSTRIALS:
# [('HON', 'AME')]
#
# Found 6 pairs in FINANCIAL:
# [('AXP', 'ICE'), ('AON', 'FIS'), ('AXP', 'CINF'), ('AJG', 'FIS'), ('AXP', 'FDS'), ('AON', 'ICE')]
#
# Found 6 pairs in TECHNOLOGY:
# [('ADSK', 'CRM'), ('ADBE', 'ADSK'), ('MSFT', 'VRSN'), ('MSFT', 'INTU'), ('MA', 'CSGP'), ('MSFT', 'V')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 3 pairs in HEALTHCARE:
# [('BSX', 'RMD'), ('ABT', 'DHR'), ('DHR', 'TMO')]
#
# Found 1 pairs in REAL ESTATE:
# [('AVB', 'UDR')]
#
# Total Pairs: 19
#
# #########################################################################
#
# Formation Period: 2018-04-10 - 2020-04-08
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('HD', 'KMX'), ('PG', 'DHI'), ('WMT', 'CMCSA'), ('WMT', 'SBUX'), ('PG', 'CMCSA')]
#
# Found 2 pairs in INDUSTRIALS:
# [('MSCI', 'ROP'), ('GRMN', 'RSG')]
#
# Found 1 pairs in FINANCIAL:
# [('AON', 'FDS')]
#
# Found 4 pairs in TECHNOLOGY:
# [('MSFT', 'VRSN'), ('MSFT', 'INTU'), ('V', 'INTU'), ('MSFT', 'ADBE')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 12
#
# #########################################################################
#
# Formation Period: 2018-07-10 - 2020-07-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 3 pairs in CONSUMER:
# [('WMT', 'SBUX'), ('PG', 'DHI'), ('DRI', 'VFC')]
#
# Found 2 pairs in INDUSTRIALS:
# [('MSCI', 'RSG'), ('MMM', 'RHI')]
#
# Found 1 pairs in FINANCIAL:
# [('USB', 'DFS')]
#
# Found 7 pairs in TECHNOLOGY:
# [('MSFT', 'ADP'), ('ADBE', 'ADSK'), ('MSFT', 'INTU'), ('LRCX', 'TXN'), ('MSFT', 'MSI'), ('MSFT', 'DXC'), ('V', 'INTU')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('DHR', 'A')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 14
#
# #########################################################################
#
# Formation Period: 2018-10-08 - 2020-10-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('HD', 'LEN'), ('HD', 'DHI')]
#
# Found 2 pairs in INDUSTRIALS:
# [('MSCI', 'UAL'), ('MTD', 'ROP')]
#
# Found 1 pairs in FINANCIAL:
# [('MET', 'PNC')]
#
# Found 4 pairs in TECHNOLOGY:
# [('MSFT', 'AMAT'), ('V', 'AMAT'), ('AMAT', 'MA'), ('ADBE', 'ADSK')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('ABT', 'HOLX')]
#
# Found 1 pairs in REAL ESTATE:
# [('EQIX', 'ESS')]
#
# Total Pairs: 11
#
# #########################################################################
#
# Formation Period: 2019-01-09 - 2021-01-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('PG', 'CL'), ('HD', 'LEN'), ('LOW', 'LEN'), ('HD', 'DHI')]
#
# Found 5 pairs in INDUSTRIALS:
# [('DE', 'PNR'), ('GRMN', 'GWW'), ('GWW', 'PH'), ('AMD', 'SPGI'), ('AMD', 'MSCI')]
#
# Found 1 pairs in FINANCIAL:
# [('MET', 'PNC')]
#
# Found 6 pairs in TECHNOLOGY:
# [('AAPL', 'TXN'), ('SNPS', 'CSGP'), ('ATVI', 'NVDA'), ('ANSS', 'CSGP'), ('AAPL', 'ADBE'), ('AAPL', 'MSFT')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('MDT', 'ZBH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 17
#
# #########################################################################
#
# Formation Period: 2019-04-10 - 2021-04-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 6 pairs in CONSUMER:
# [('HD', 'LEN'), ('KMX', 'PHM'), ('HD', 'DHI'), ('LOW', 'LEN'), ('EXPE', 'DRI'), ('DHI', 'LEN')]
#
# Found 6 pairs in INDUSTRIALS:
# [('CAT', 'CSX'), ('UNP', 'AME'), ('GRMN', 'GWW'), ('ETN', 'GWW'), ('AMD', 'MSCI'), ('DE', 'PNR')]
#
# Found 2 pairs in FINANCIAL:
# [('BAC', 'TFC'), ('MET', 'PNC')]
#
# Found 8 pairs in TECHNOLOGY:
# [('AAPL', 'ACN'), ('LRCX', 'TXN'), ('ATVI', 'ANSS'), ('MCHP', 'APH'), ('ATVI', 'SNPS'), ('AAPL', 'INTU'), ('GOOGL', 'LRCX'), ('ATVI', 'NVDA')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 3 pairs in HEALTHCARE:
# [('DVA', 'HOLX'), ('UNH', 'HUM'), ('DHR', 'IDXX')]
#
# Found 1 pairs in REAL ESTATE:
# [('BXP', 'VNO')]
#
# Total Pairs: 26
#
# #########################################################################
#
# Formation Period: 2019-07-11 - 2021-07-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 5 pairs in CONSUMER:
# [('EXPE', 'TPR'), ('HD', 'LEN'), ('EXPE', 'YUM'), ('HD', 'DHI'), ('EXPE', 'DRI')]
#
# Found 5 pairs in INDUSTRIALS:
# [('GRMN', 'GWW'), ('CAT', 'CSX'), ('DE', 'SWK'), ('GWW', 'ITW'), ('ETN', 'GWW')]
#
# Found 2 pairs in FINANCIAL:
# [('BAC', 'TFC'), ('PNC', 'TFC')]
#
# Found 17 pairs in TECHNOLOGY:
# [('GOOGL', 'SNPS'), ('MSFT', 'ACN'), ('SWKS', 'TXN'), ('MSFT', 'CDNS'), ('ADI', 'ACN'), ('GOOGL', 'TXN'), ('NVDA', 'ANSS'), ('LRCX', 'QCOM'), ('MSFT', 'SNPS'), ('ADSK', 'SNPS'), ('ADI', 'APH'), ('NVDA', 'SNPS'), ('GLW', 'SNA'), ('MSFT', 'INTU'), ('MSFT', 'ATVI'), ('V', 'MA'), ('GOOGL', 'AMAT')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 3 pairs in HEALTHCARE:
# [('A', 'HOLX'), ('DHR', 'LH'), ('ALGN', 'LH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 32
#
# #########################################################################
#
# Formation Period: 2019-10-09 - 2021-10-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 7 pairs in CONSUMER:
# [('CMCSA', 'LEN'), ('CMCSA', 'NWL'), ('NWL', 'TPR'), ('HD', 'LEN'), ('HD', 'DHI'), ('IPG', 'LKQ'), ('DHI', 'LEN')]
#
# Found 2 pairs in INDUSTRIALS:
# [('AME', 'GWW'), ('CSX', 'AME')]
#
# Found 3 pairs in FINANCIAL:
# [('PRU', 'TFC'), ('PNC', 'TFC'), ('FITB', 'PNC')]
#
# Found 4 pairs in TECHNOLOGY:
# [('GOOGL', 'ADI'), ('ADI', 'APH'), ('ADI', 'ACN'), ('INTU', 'SNPS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('JNJ', 'LLY')]
#
# Found 2 pairs in HEALTHCARE:
# [('LH', 'WAT'), ('DHR', 'TMO')]
#
# Found 1 pairs in REAL ESTATE:
# [('CBRE', 'EXR')]
#
# Total Pairs: 20
#
# #########################################################################
#
# Formation Period: 2020-01-09 - 2022-01-06
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 4 pairs in CONSUMER:
# [('MCD', 'PHM'), ('LOW', 'MCK'), ('IPG', 'LKQ'), ('DHI', 'LEN')]
#
# Found 1 pairs in INDUSTRIALS:
# [('ETN', 'PH')]
#
# Found 3 pairs in FINANCIAL:
# [('PNC', 'TFC'), ('BAC', 'TFC'), ('BAC', 'PRU')]
#
# Found 4 pairs in TECHNOLOGY:
# [('GOOGL', 'LRCX'), ('GOOGL', 'AMAT'), ('ADI', 'MCHP'), ('MSFT', 'CDNS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 1 pairs in REAL ESTATE:
# [('EXR', 'PSA')]
#
# Total Pairs: 13
#
# #########################################################################
#
# Formation Period: 2020-04-09 - 2022-04-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('ABC', 'GPC'), ('DHI', 'LEN')]
#
# Found 3 pairs in INDUSTRIALS:
# [('EXPD', 'PNR'), ('MCO', 'SPGI'), ('ETN', 'TEL')]
#
# Found 1 pairs in FINANCIAL:
# [('USB', 'LNC')]
#
# Found 6 pairs in TECHNOLOGY:
# [('ADI', 'MCHP'), ('ADP', 'IT'), ('NVDA', 'SNPS'), ('INTU', 'SNPS'), ('MSFT', 'SNPS'), ('INTU', 'CDNS')]
#
# Found 0 pairs in ENERGY:
# []
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 3 pairs in REAL ESTATE:
# [('MAA', 'WY'), ('PLD', 'PSA'), ('AVB', 'ESS')]
#
# Total Pairs: 15
#
# #########################################################################
#
# Formation Period: 2020-07-10 - 2022-07-11
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 1 pairs in CONSUMER:
# [('IPG', 'YUM')]
#
# Found 6 pairs in INDUSTRIALS:
# [('BR', 'PNR'), ('PEG', 'PWR'), ('PAYX', 'PEG'), ('MCO', 'SPGI'), ('AME', 'TEL'), ('DOV', 'MTD')]
#
# Found 2 pairs in FINANCIAL:
# [('AFL', 'L'), ('AIG', 'AFL')]
#
# Found 1 pairs in TECHNOLOGY:
# [('NVDA', 'MSI')]
#
# Found 1 pairs in ENERGY:
# [('COP', 'EOG')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 2 pairs in REAL ESTATE:
# [('PSA', 'WELL'), ('AVB', 'UDR')]
#
# Total Pairs: 13
#
# #########################################################################
#
# Formation Period: 2020-10-08 - 2022-10-07
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('KMX', 'MHK'), ('IPG', 'YUM')]
#
# Found 0 pairs in INDUSTRIALS:
# []
#
# Found 0 pairs in FINANCIAL:
# []
#
# Found 1 pairs in TECHNOLOGY:
# [('AMAT', 'TXN')]
#
# Found 1 pairs in ENERGY:
# [('COP', 'DVN')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 0 pairs in HEALTHCARE:
# []
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 4
#
# #########################################################################
#
# Formation Period: 2021-01-08 - 2023-01-09
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 0 pairs in CONSUMER:
# []
#
# Found 1 pairs in INDUSTRIALS:
# [('MMM', 'FDX')]
#
# Found 1 pairs in FINANCIAL:
# [('BAC', 'BK')]
#
# Found 0 pairs in TECHNOLOGY:
# []
#
# Found 1 pairs in ENERGY:
# [('COP', 'EOG')]
#
# Found 1 pairs in FOOD:
# [('HSY', 'DPZ')]
#
# Found 0 pairs in PHARMACEUTICALS:
# []
#
# Found 1 pairs in HEALTHCARE:
# [('TFX', 'ZBH')]
#
# Found 0 pairs in REAL ESTATE:
# []
#
# Total Pairs: 5
#
# #########################################################################
#
# Formation Period: 2021-04-12 - 2023-04-11
#
# Found 0 pairs in MATERIALS:
# []
#
# Found 2 pairs in CONSUMER:
# [('AMZN', 'TTWO'), ('CMCSA', 'CHD')]
#
# Found 1 pairs in INDUSTRIALS:
# [('GPN', 'SPGI')]
#
# Found 1 pairs in FINANCIAL:
# [('TRV', 'AFL')]
#
# Found 0 pairs in TECHNOLOGY:
# []
#
# Found 1 pairs in ENERGY:
# [('COP', 'EOG')]
#
# Found 0 pairs in FOOD:
# []
#
# Found 1 pairs in PHARMACEUTICALS:
# [('LLY', 'CRL')]
#
# Found 3 pairs in HEALTHCARE:
# [('XRAY', 'ZBH'), ('ILMN', 'DVA'), ('ILMN', 'ALGN')]
#
# Found 1 pairs in REAL ESTATE:
# [('EQR', 'UDR')]
#
# Total Pairs: 10

# %%
def calculate_metrics(cumret):
    '''
    calculate performance metrics from cumulative returns
    '''
    if len(cumret) == 0:
        return 0, 0, 0, 0, 0
    total_return = (cumret[-1] - cumret[0])/cumret[0]
    apr = (1+total_return)**(252/len(cumret)) - 1
    rets = pd.DataFrame(cumret).pct_change()
    sharpe = np.sqrt(252) * np.nanmean(rets) / np.nanstd(rets)
    
    # maxdd and maxddd
    highwatermark=np.zeros(cumret.shape)
    drawdown=np.zeros(cumret.shape)
    drawdownduration=np.zeros(cumret.shape)
    for t in np.arange(1, cumret.shape[0]):
        highwatermark[t]=np.maximum(highwatermark[t-1], cumret[t])
        drawdown[t]=cumret[t]/highwatermark[t]-1
        if drawdown[t]==0:
            drawdownduration[t]=0
        else:
            drawdownduration[t]=drawdownduration[t-1]+1
    maxDD=np.min(drawdown)
    maxDDD=np.max(drawdownduration)
    
    return total_return, apr, sharpe, maxDD, maxDDD

# %% [markdown]
# ### PnL of the first 3 pairs

# %%
for _, key in enumerate(list(backtest_result.keys())[:3]):
    temp = pd.concat(backtest_result[key], axis=0)
    # calculate cumulative return
    cumret = np.nancumprod(1 + temp)
    # plot
    plt.figure(figsize=(18, 10))
    plt.plot(temp.index, cumret)
    plt.title(f"{key} Equity")
    plt.show()
    # calculate metrics
    total_return, apr, sharpe, maxDD, maxDDD = calculate_metrics(cumret)
    print(f"Total-Ret: {total_return}, Annual-Ret: {apr}, Sharpe: {sharpe}, \n"
          f"maxDD: {maxDD}, MaxDD-Duration: {maxDDD}")
# Out:
# Total-Ret: 0.08973008070363608, Annual-Ret: 0.40263064514913105, Sharpe: 3.056097444353811,
# maxDD: 0.0, MaxDD-Duration: 0.0
# Total-Ret: 0.06789817560711664, Annual-Ret: 0.13806778876439263, Sharpe: 1.2903756136306865,
# maxDD: -0.0722570482854058, MaxDD-Duration: 45.0
# Total-Ret: 0.0, Annual-Ret: 0.0, Sharpe: nan,
# maxDD: 0.0, MaxDD-Duration: 0.0

# %% [markdown]
# # Performance Summary
# The Mutual Information strategy under 20x leverage provided significant reductions in volatility and drawdown when compared to the S&P500, with the Sharpe Ratio and Maximum Drawdown respectively of **1.64** and only **-6.65%** from the MI strategy as opposed to **0.78** and **-33.92%** from the Index. Albeit the S&P500's ROI is more than twice of the MI strategy, but with such low volatility, leverage can be safely raised to achieve greater returns.

# %%
temp_equity = {}
for i in backtest_result.keys():
    backtest_result[i] = pd.concat(backtest_result[i])
    backtest_result[i] = backtest_result[i][~backtest_result[i].index.duplicated()]
    # remove euity[i] with all nan values
    if backtest_result[i].isnull().all():
        continue
    else:
        temp_equity[i] = backtest_result[i]
    
    
# concat all pd.Sereis in temp_equity, column-wise
df = pd.concat(temp_equity, axis=1)
df.columns = [key for key in temp_equity.keys()]
df.index = pd.to_datetime(df.index)
df.fillna(0, inplace=True)
df = df.sort_index()

num_pairs = len(df.columns)
# sum up the daily returns across all columns
df['total'] = df.sum(axis=1) / num_pairs
# calculate the cumulative returns
cumret_main = np.nancumprod((df['total'] * 20) + 1) # 20 Leverage
# plot the total equity curve
expected_ret = df['total'].mean()
# plot the total equity curve
fig, ax = plt.subplots(2, 1, figsize=(20, 30))
ax[0].plot(df.index, cumret_main)
ax[0].set_title(f"Total Equity", fontsize=20)
# plot the histogram of the  pd series
ax[1].hist(df['total']*100, bins=100)
ax[1].axvline(expected_ret*100, ls='--', color='r', linewidth=3, label="Mean")
ax[1].set_title(f"Return Distribution", fontsize=20)
ax[1].legend([f"Mean: {round(expected_ret*100, 4)}%"], fontsize=20);

# %% [markdown]
# Compare with the S&P500 performance

# %%
# SP500 cumulative return
start = df.index[0]
end = df.index[-1]
spx_prices = yf.Ticker("^GSPC").history(start=start, end=end)
spx_ret = spx_prices['Close'].pct_change()
cumret_baseline = np.nancumprod(spx_ret + 1)

# %%
metrics_df = pd.DataFrame(index=['Total return', 'APR', 'Sharpe ratio', 'Max Drawdown', 'Max Drawdown Duration'], 
             columns=['S&P500', 'Mutual Information Portfolio'])
metrics_df['S&P500'] = calculate_metrics(cumret_baseline)
metrics_df['Mutual Information Portfolio'] = calculate_metrics(cumret_main)
metrics_df
# Out:
#                            S&P500  Mutual Information Portfolio
# Total return             2.852819                      1.589800
# APR                      0.111587                      0.077464
# Sharpe ratio             0.690999                      3.740048
# Max Drawdown            -0.339250                     -0.017777
# Max Drawdown Duration  381.000000                    121.000000

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this research, a profitable trading strategy was demonstrated by establishing the mean reverting nonlinear relationships between S&P500 stock composite. The mutual information between security prices was calculated as a measure of generalized correlation. Securities with high mutual information scores were selected and nonlinear relationships were estimated through cross-validated polynomial regression. Rigorous testing was conducted to filter the potential pairs to pairs that obtained mean reverting and stationary spreads. Trade signals were then generated by modeling the spreads as a GARCH(1, 1) process.
#
# Many improvements can be made to this research. For example, increasing the stock universe to generate more potential pairs. Implementation of various portfolio optimization techniques at the total-portfolio level to better allocate wealth to pair-portfolio level. Increasing the grid search and cross validation folds.
